# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Openning data

# %%
# tests/preprocessing/datasets.ipynb
from pathlib import Path
import sys, os

# point to your project root
project_root = Path(r"/home/galencarmedeiro/git/postdoc/ragtree")
#project_root = Path(r"C:\Users\henri\Documents\git\post-doc\ragtree")
os.chdir(project_root)  # so relative paths go to data/, not tests/
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print("CWD:", os.getcwd())
# Out:
# CWD: /home/galencarmedeiro/git/postdoc/ragtree

# %%
# %run "scripts/run_single_llm_baseline.py" --dataset-key maven_ere --backend vllm
# Out:
# [runner] dataset-key=maven_ere
# [runner] method=baseline
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/maven_ere.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/maven_ere.baseline.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=all
# Running baseline on maven_ere: 0doc [00:00, ?doc/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/git/postdoc/ragtree/scripts/run_single_llm_baseline.py:137
#     122     run_relation_experiment(
#     123         strategy_cls=BaselineRelationStrategy,
#     124         config_path=args.config,
#    (...)    132         prepare_context_fn=None,
#     133     )
#     136 if __name__ == "__main__":
# --> 137     main()
#
# File ~/git/postdoc/ragtree/scripts/run_single_llm_baseline.py:122, in main()
# ...

# %%
# %run "scripts/run_single_llm_baseline.py" --dataset-key fincausal --backend vllm
# Out:
# [baseline] dataset-key=fincausal
# [baseline] backend=vllm, model=openai/gpt-oss-20b
# [baseline] input=data\preprocessed\fincausal.jsonl
# [baseline] output=C:\Users\henri\Documents\git\post-doc\ragtree\data\processed\fincausal.baseline.vllm.jsonl
# [baseline] output-format=full
# 0it [00:00, ?it/s]
# ['CAUSE']
# ...

# %%
# %run "scripts/run_single_llm_baseline.py" --dataset-key docred_causal --backend vllm
# Out:
# [baseline] dataset-key=docred_causal
# [baseline] backend=vllm, model=openai/gpt-oss-20b
# [baseline] input=data\preprocessed\docred_causal.jsonl
# [baseline] output=C:\Users\henri\Documents\git\post-doc\ragtree\data\processed\docred_causal.baseline.vllm.jsonl
# [baseline] output-format=full
# [baseline] Loaded DocRED rel_info with 96 entries.
# 5it [01:29, 17.84s/it]
# [baseline] Done. Processed 5 documents.

# %%
try:
    # %run "scripts/run_single_llm_baseline.py" --dataset-key causalbank --backend vllm
except Exception as e:
    print(e)
# Out:
# [runner] dataset-key=causalbank
# [runner] method=baseline
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/causalbank.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.baseline.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=all
# Running baseline on causalbank: 1080doc [1:19:32,  4.42s/doc]
# [runner] Done. Processed 1080 documents.

# %%
try:
    # %run "scripts/run_icl_baseline.py" --dataset-key causalbank --backend vllm --icl-train-type resulted_from --icl-train-num 3 --icl-predict-types all
except Exception as e:
    print(e)

try:
    # %run "scripts/run_icl_baseline.py" --dataset-key eventstoryline --backend vllm --icl-train-type full --icl-train-num 3 --icl-predict-types all
except Exception as e:
    print(e)


try:
    # %run "scripts/run_icl_baseline.py" --dataset-key fincausal --backend vllm --icl-train-type train.csv --icl-train-num 3 --icl-predict-types all
except Exception as e:
    print(e)


try:
    # %run "scripts/run_icl_baseline.py" --dataset-key maven_ere --backend vllm --icl-train-type train --icl-train-num 3 --icl-predict-types all
except Exception as e:
    print(e)
# Out:
# [runner] dataset-key=causalbank
# [runner] method=icl
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/causalbank.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.icl.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=all
# ...
# [icl] Collected 3 few-shot examples of type 'resulted_from'.
# Running icl on causalbank: 1080doc [1:28:47,  4.93s/doc]
# [runner] Done. Processed 1080 documents.
# [runner] dataset-key=eventstoryline
# [runner] method=icl
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/eventstoryline.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/eventstoryline.icl.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=all
# ...
# [icl] Collected 3 few-shot examples of type 'full'.
# Running icl on eventstoryline: 443doc [2:08:17, 17.38s/doc]
# [runner] Done. Processed 443 documents.
# ...

# %%
try:
    # %run "scripts/run_single_llm_baseline.py" --dataset-key maven_ere --backend vllm
except Exception as e:
    print(e)

try:
    # %run "scripts/run_icl_baseline.py" --dataset-key maven_ere --backend vllm --icl-train-type train --icl-train-num 3 --icl-predict-types all
except Exception as e:
    print(e)
# Out:
# [runner] dataset-key=maven_ere
# [runner] method=baseline
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/maven_ere.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/maven_ere.baseline.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=all
# Running baseline on maven_ere: 3516doc [14:43:01, 15.07s/doc]
# [runner] Done. Processed 3516 documents.
# [runner] dataset-key=maven_ere
# [runner] method=icl
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/maven_ere.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/maven_ere.icl.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=all
# ...
# [icl] Collected 3 few-shot examples of type 'train'.
# Running icl on maven_ere: 3516doc [17:57:17, 18.38s/doc]
# [runner] Done. Processed 3516 documents.
# [runner] dataset-key=docred_causal
# [runner] method=baseline
# ...

# %%
try:
    # %run "scripts/run_single_llm_baseline.py" --dataset-key docred_causal --backend vllm --doc-type dev
except Exception as e:
    print(e)


try:
    # %run "scripts/run_cot_baseline.py" --dataset-key docred_causal --backend vllm --doc-type dev 
except Exception as e:
    print(e)

try:
    # %run "scripts/run_icl_baseline.py" --dataset-key docred_causal --backend vllm --icl-train-type train_annotated --icl-train-num 3 --icl-predict-types dev
except Exception as e:
    print(e)
# Out:
# [runner] dataset-key=docred_causal
# [runner] method=baseline
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/docred_causal.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.baseline.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=['dev']
# [runner] Loaded DocRED rel_info with 96 entries.
# Running baseline on docred_causal: 106924doc [5:30:21,  5.39doc/s]
# [runner] Done. Processed 998 documents.
# [runner] Skipped 105926 documents due to doc-type filter.
# [runner] dataset-key=docred_causal
# [runner] method=cot
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/docred_causal.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.cot.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=dev
# [runner] Loaded DocRED rel_info with 96 entries.
# ...

# %%
try:
    # %run "scripts/run_cot_baseline.py" --dataset-key docred_causal --backend vllm --doc-type test 
except Exception as e:
    print(e)
# Out:
# [runner] dataset-key=docred_causal
# [runner] method=cot
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/docred_causal.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.cot.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=test
# [runner] Loaded DocRED rel_info with 96 entries.
# Running cot on docred_causal: 1248doc [3:03:18,  8.81s/doc]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/git/postdoc/ragtree/scripts/run_cot_baseline.py:116
#     101     run_relation_experiment(
#     102         strategy_cls=ChainOfThoughtRelationStrategy,
#     103         config_path=args.config,
#    (...)    111         prepare_context_fn=lambda ip, cfg: _prep(ip, cfg),
#     112     )
#     115 if __name__ == "__main__":
# --> 116     main()
#
# ...

# %%
try:
    # %run "scripts/run_cot_baseline.py" --dataset-key eventstoryline --backend vllm --doc-type all 
except Exception as e:
    print(e)

try:
    # %run "scripts/run_cot_baseline.py" --dataset-key fincausal --backend vllm --doc-type all 
except Exception as e:
    print(e)

try:
    # %run "scripts/run_cot_baseline.py" --dataset-key causalbank --backend vllm --doc-type all 
except Exception as e:
    print(e)

try:
    # %run "scripts/run_cot_baseline.py" --dataset-key maven_ere --backend vllm --doc-type all 
except Exception as e:
    print(e)
# Out:
# [runner] dataset-key=eventstoryline
# [runner] method=baseline
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/eventstoryline.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/eventstoryline.baseline.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=all
# Running baseline on eventstoryline: 443doc [4:06:47, 33.43s/doc]
# [runner] Done. Processed 443 documents.
# [runner] dataset-key=fincausal
# [runner] method=baseline
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/fincausal.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/fincausal.baseline.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=all
# Running baseline on fincausal: 967doc [1:52:40,  6.99s/doc]
# [runner] Done. Processed 967 documents.
# [runner] dataset-key=causalbank
# [runner] method=baseline
# [runner] backend=vllm, model=openai/gpt-oss-20b
# ...
