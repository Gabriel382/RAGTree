# %%
# %load_ext autoreload
# %autoreload 2

# %%
# tests/preprocessing/datasets.ipynb
from pathlib import Path
import sys, os

# point to your project root
project_root = Path(r"C:\Users\henri\Documents\git\post-doc\ragtree")
os.chdir(project_root)  # so relative paths go to data/, not tests/
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print("CWD:", os.getcwd())
# Out:
# CWD: C:\Users\henri\Documents\git\post-doc\ragtree

# %%
from ragtree.core.config import load_config
from ragtree.datasets.causalbank import CausalBankDataset

cfg = load_config()
ds = CausalBankDataset(cfg["datasets"]["causalbank"])

first10 = []
for i, doc in enumerate(ds.load()):
    first10.append(doc)
    if i == 9:
        break

first10
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       5 ds = CausalBankDataset(cfg["datasets"]["causalbank"])
#       7 first10 = []
# ----> 8 for i, doc in enumerate(ds.load()):
#       9     first10.append(doc)
#      10     if i == 9:
#
# File ~\Documents\git\post-doc\ragtree\ragtree\datasets\causalbank.py:15, in CausalBankDataset.load(self)
#      13 def load(self) -> Iterable[Dict[str, Any]]:
#      14     if not self.path.exists():
# ---> 15         raise FileNotFoundError(
#      16             f"CausalBank file not found at {self.path}. "
#      17             "Download it and place it there (configs.paths.data_raw)."
#      18         )
#      19     with self.path.open("r", encoding="utf-8") as f:
#      20         reader = csv.DictReader(f, delimiter="\t")
#
# FileNotFoundError: CausalBank file not found at data\raw\causalbank.jsonl. Download it and place it there (configs.paths.data_raw).
