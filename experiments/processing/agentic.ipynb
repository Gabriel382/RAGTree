# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Openning data

# %%
# tests/preprocessing/datasets.ipynb
from pathlib import Path
import sys, os

# point to your project root
project_root = Path(r"/home/galencarmedeiro/git/postdoc/ragtree")
#project_root = Path(r"C:\Users\henri\Documents\git\post-doc\ragtree")
os.chdir(project_root)  # so relative paths go to data/, not tests/
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print("CWD:", os.getcwd())
# Out:
# CWD: /home/galencarmedeiro/git/postdoc/ragtree

# %% [markdown]
# # Docred

# %%
# %run "scripts/run_ontology_linking.py" \
  --dataset-key docred_causal \
  --ontology-key docredontology \
  --method llm_embedding \
  --doc-types dev

# %%
# %run "scripts/build_kg_from_preprocessed.py" \
  --dataset-key docred_causal \
  --doc-types train_annotated \
  --skip 0
# Out:
# [kg] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/kg/docred_causal__types=train_annotated_skip=0_limit=None__kg.json
# [kg] stats: {'num_docs': 3053, 'num_triples': 38180, 'num_nodes': 59493, 'num_edges': 38180}

# %% [markdown]
# #### Agentic Single Simple RAG

# %%
# %run "scripts/run_langgraph_agentic_simple_relations.py" \
  --dataset-key docred_causal \
  --backend vllm \
  --doc-types dev \
  --shot-num 3 \
  --shot-doc-types all \
  --max-llm-calls 2
# Out:
# [langgraph_agentic_simple] Loaded DocRED rel_info with 96 entries.
# [langgraph_agentic_simple] input=data/preprocessed/docred_causal.jsonl
# [langgraph_agentic_simple] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.langgraph_agentic_simple.vllm.jsonl
# [langgraph_agentic_simple] predict doc-types=['dev'] skip=0 limit=None
# [langgraph_agentic_simple] backend=vllm model=openai/gpt-oss-20b
# [langgraph_agentic_simple] planner_mode=rule max_llm_calls=2 web=True wikidata=True
# [langgraph_agentic_simple] few-shots collected: 3
# LangGraphAgenticSimple on docred_causal: 106924doc [6:10:53,  4.80doc/s]
# [langgraph_agentic_simple] done. predicted=998
# [langgraph_agentic_simple] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.langgraph_agentic_simple.vllm.jsonl

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key docred_causal \
  --method langgraph_agentic_simple \
  --backend vllm \
  --doc-type dev
# Out:
# [eval] dataset-key: docred_causal
# [eval] method: langgraph_agentic_simple
# [eval] backend: vllm
# [eval] doc-type: dev
# [eval] gold: data/preprocessed/docred_causal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.langgraph_agentic_simple.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/docred_causal/langgraph_agentic_simple.vllm.dev.json
#
# === Micro-level metrics ===
# Precision: 0.2838
# Recall:    0.0390
# F1:        0.0686
#
# === Counts ===
# TP: 479
# FP: 1209
# FN: 11796
# num_docs_seen: 998
# num_docs_eval: 998
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# #### Agent Single Hybrid RAG

# %%
# %run "scripts/run_agentic_hybrid_relations.py" \
  --dataset-key docred_causal \
  --backend vllm \
  --doc-types dev \
  --ontology-links-path data/preprocessed/docred_causal_olink_llm_embedding_onto_docredontology.jsonl \
  --ontology-key docredontology \
  --ontology-method llm_embedding \
  --kg-path data/kg/docred_causal__types=train_annotated_skip=0_limit=None__kg.json \
  --shot-num 3 \
  --shot-doc-types all \
  --max-llm-calls 1
# Out:
# [agentic_hybrid] Loaded DocRED rel_info with 96 entries.
# [agentic_hybrid] input=data/preprocessed/docred_causal.jsonl
# [agentic_hybrid] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.agentic_hybrid.vllm.jsonl
# [agentic_hybrid] ontology_artifact=data/preprocessed/docred_causal_olink_llm_embedding_onto_docredontology.jsonl
# [agentic_hybrid] kg_artifact=data/kg/docred_causal__types=train_annotated_skip=0_limit=None__kg.json
# [agentic_hybrid] predict doc-types=['dev'] skip=0 limit=None
# [agentic_hybrid] backend=vllm model=openai/gpt-oss-20b
# [agentic_hybrid] few-shots collected: 3
# AgenticHybrid on docred_causal: 106924doc [5:54:00,  5.03doc/s]
# [agentic_hybrid] done. predicted=998
# [agentic_hybrid] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.agentic_hybrid.vllm.jsonl

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key docred_causal \
  --method agentic_hybrid \
  --backend vllm \
  --doc-type dev
# Out:
# [eval] dataset-key: docred_causal
# [eval] method: agentic_hybrid
# [eval] backend: vllm
# [eval] doc-type: dev
# [eval] gold: data/preprocessed/docred_causal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.agentic_hybrid.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/docred_causal/agentic_hybrid.vllm.dev.json
#
# === Micro-level metrics ===
# Precision: 0.3239
# Recall:    0.0890
# F1:        0.1396
#
# === Counts ===
# TP: 1092
# FP: 2279
# FN: 11183
# num_docs_seen: 998
# num_docs_eval: 998
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# #### LangGraph Single Agentic RAG

# %%
# %run "scripts/run_langgraph_agentic_hybrid_relations.py" \
  --dataset-key docred_causal \
  --backend vllm \
  --doc-types dev \
  --ontology-links-path data/preprocessed/docred_causal_olink_llm_embedding_onto_docredontology.jsonl \
  --ontology-key docredontology \
  --ontology-method llm_embedding \
  --kg-path data/kg/docred_causal__types=train_annotated_skip=0_limit=None__kg.json \
  --kg-max-triples 40 \
  --shot-num 0 \
  --planner-mode llm \
  --enable-web \
  --enable-wikidata \
  --max-llm-calls 2
# Out:
# [langgraph_agentic_hybrid] Loaded DocRED rel_info with 96 entries.
# [langgraph_agentic_hybrid] input=data/preprocessed/docred_causal.jsonl
# [langgraph_agentic_hybrid] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.langgraph_agentic_hybrid.vllm.jsonl
# [langgraph_agentic_hybrid] ontology_artifact=data/preprocessed/docred_causal_olink_llm_embedding_onto_docredontology.jsonl
# [langgraph_agentic_hybrid] kg_artifact=data/kg/docred_causal__types=train_annotated_skip=0_limit=None__kg.json
# [langgraph_agentic_hybrid] predict doc-types=['dev'] skip=0 limit=None
# [langgraph_agentic_hybrid] backend=vllm model=openai/gpt-oss-20b
# [langgraph_agentic_hybrid] planner_mode=llm max_llm_calls=2 web=True wikidata=True
# LangGraphAgenticHybrid on docred_causal: 106924doc [10:11:31,  2.91doc/s]
# [langgraph_agentic_hybrid] done. predicted=998
# [langgraph_agentic_hybrid] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.langgraph_agentic_hybrid.vllm.jsonl

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key docred_causal \
  --method langgraph_agentic_hybrid  \
  --backend vllm \
  --doc-type dev
# Out:
# [eval] dataset-key: docred_causal
# [eval] method: langgraph_agentic_hybrid
# [eval] backend: vllm
# [eval] doc-type: dev
# [eval] gold: data/preprocessed/docred_causal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.langgraph_agentic_hybrid.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/docred_causal/langgraph_agentic_hybrid.vllm.dev.json
#
# === Micro-level metrics ===
# Precision: 0.2510
# Recall:    0.1799
# F1:        0.2096
#
# === Counts ===
# TP: 2208
# FP: 6590
# FN: 10067
# num_docs_seen: 998
# num_docs_eval: 998
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# #### MARAG

# %%
# %run "scripts/run_marag_relations.py" \
  --dataset-key docred_causal \
  --backend vllm \
  --doc-types dev \
  --ontology-key docredontology \
  --ontology-links-path data/preprocessed/docred_causal_olink_llm_embedding_onto_docredontology.jsonl \
  --kg-path data/kg/docred_causal__types=train_annotated_skip=0_limit=None__kg.json \
  --enable-web \
  --enable-wikidata \
  --max-llm-calls 10 \
  --shot-num 3 \
  --shot-type dev
# Out:
# [marag] input=data/preprocessed/docred_causal.jsonl
# [marag] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.marag.vllm.jsonl
# [marag] ontology_artifact=data/preprocessed/docred_causal_olink_llm_embedding_onto_docredontology.jsonl
# [marag] kg_artifact=data/kg/docred_causal__types=train_annotated_skip=0_limit=None__kg.json
# [marag] predict doc-types=['dev'] skip=0 limit=None
# [marag] backend=vllm model=openai/gpt-oss-20b
# [marag] docs matching filter before skip/limit: 998
# [marag] docs to process after skip/limit: 998
# [marag] few-shots collected: 3
# MA-RAG on docred_causal:  66%|██████▋   | 662/998 [2:47:26<1:19:43, 14.24s/doc]

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key docred_causal \
  --method marag \
  --backend vllm \
  --doc-type dev
# Out:
# [eval] dataset-key: docred_causal
# [eval] method: marag
# [eval] backend: vllm
# [eval] doc-type: dev
# [eval] gold: data/preprocessed/docred_causal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.marag.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/docred_causal/marag.vllm.dev.json
#
# === Micro-level metrics ===
# Precision: 0.6667
# Recall:    0.0442
# F1:        0.0829
#
# === Counts ===
# TP: 38
# FP: 19
# FN: 822
# num_docs_seen: 63
# num_docs_eval: 63
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# # EventStoryLine

# %%
try:
    # %run "scripts/run_ontology_linking.py" --dataset-key eventstoryline --ontology-key owltime --method llm_embedding --doc-types all
except Exception as e:
    print(e)

# %%
# %run "scripts/build_kg_from_preprocessed.py" \
  --dataset-key eventstoryline \
  --doc-types full \
  --limit 10

# %% [markdown]
# #### Agent Single Hybrid RAG

# %%
# %run "scripts/run_agentic_hybrid_relations.py" \
  --dataset-key eventstoryline \
  --backend vllm \
  --doc-types all \
  --ontology-links-path data/preprocessed/eventstoryline_olink_llm_embedding_onto_owltime.jsonl \
  --ontology-key owltime \
  --ontology-method llm_embedding \
  --kg-path data/kg/eventstoryline__types=full_skip=0_limit=10__kg.json \
  --shot-num 3 \
  --shot-doc-types all \
  --max-llm-calls 1
# Out:
# [agentic_hybrid] input=data/preprocessed/eventstoryline.jsonl
# [agentic_hybrid] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/eventstoryline.agentic_hybrid.vllm.jsonl
# [agentic_hybrid] ontology_artifact=data/preprocessed/eventstoryline_olink_llm_embedding_onto_owltime.jsonl
# [agentic_hybrid] kg_artifact=data/kg/eventstoryline__types=full_skip=0_limit=10__kg.json
# [agentic_hybrid] predict doc-types=all skip=0 limit=None
# [agentic_hybrid] backend=vllm model=openai/gpt-oss-20b
# [agentic_hybrid] few-shots collected: 3
# AgenticHybrid on eventstoryline: 443doc [5:00:06, 40.65s/doc]
# [agentic_hybrid] done. predicted=443
# [agentic_hybrid] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/eventstoryline.agentic_hybrid.vllm.jsonl

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key eventstoryline \
  --method agentic_hybrid \
  --backend vllm \
  --doc-type all
# Out:
# [eval] dataset-key: eventstoryline
# [eval] method: agentic_hybrid
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/eventstoryline.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/eventstoryline.agentic_hybrid.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/eventstoryline/agentic_hybrid.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.2086
# Recall:    0.0732
# F1:        0.1084
#
# === Counts ===
# TP: 706
# FP: 2678
# FN: 8934
# num_docs_seen: 443
# num_docs_eval: 443
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# #### Agentic Single Simple RAG

# %%
# %run "scripts/run_langgraph_agentic_simple_relations.py" \
  --dataset-key eventstoryline \
  --backend vllm \
  --doc-types all \
  --shot-num 3 \
  --shot-doc-types all \
  --max-llm-calls 2
# Out:
# [langgraph_agentic_simple] input=data/preprocessed/eventstoryline.jsonl
# [langgraph_agentic_simple] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/eventstoryline.langgraph_agentic_simple.vllm.jsonl
# [langgraph_agentic_simple] predict doc-types=all skip=0 limit=None
# [langgraph_agentic_simple] backend=vllm model=openai/gpt-oss-20b
# [langgraph_agentic_simple] planner_mode=rule max_llm_calls=2 web=True wikidata=True
# [langgraph_agentic_simple] few-shots collected: 3
# LangGraphAgenticSimple on eventstoryline: 443doc [4:22:02, 35.49s/doc]
# [langgraph_agentic_simple] done. predicted=443
# [langgraph_agentic_simple] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/eventstoryline.langgraph_agentic_simple.vllm.jsonl

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key eventstoryline \
  --method langgraph_agentic_simple \
  --backend vllm \
  --doc-type all
# Out:
# [eval] dataset-key: eventstoryline
# [eval] method: langgraph_agentic_simple
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/eventstoryline.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/eventstoryline.langgraph_agentic_simple.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/eventstoryline/langgraph_agentic_simple.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.1780
# Recall:    0.0635
# F1:        0.0936
#
# === Counts ===
# TP: 612
# FP: 2827
# FN: 9028
# num_docs_seen: 443
# num_docs_eval: 443
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# # FinCausal

# %%
try:
    # %run "scripts/run_ontology_linking.py" --dataset-key fincausal --ontology-key fibocoreplus --method llm_embedding --doc-types all
except Exception as e:
    print(e)

# %%
# %run "scripts/build_kg_from_preprocessed.py" \
  --dataset-key fincausal \
  --doc-types train.csv \
  --skip 0

# %% [markdown]
# #### Agent Single Hybrid RAG

# %%
# %run "scripts/run_agentic_hybrid_relations.py" \
  --dataset-key fincausal \
  --backend vllm \
  --doc-types all \
  --ontology-links-path data/preprocessed/fincausal_olink_llm_embedding_onto_fibocoreplus.jsonl \
  --ontology-key fibocoreplus \
  --ontology-method llm_embedding \
  --kg-path data/kg/fincausal__types=train.csv_skip=0_limit=None__kg.json \
  --shot-num 3 \
  --shot-doc-types all \
  --max-llm-calls 1
# Out:
# [agentic_hybrid] input=data/preprocessed/fincausal.jsonl
# [agentic_hybrid] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/fincausal.agentic_hybrid.vllm.jsonl
# [agentic_hybrid] ontology_artifact=data/preprocessed/fincausal_olink_llm_embedding_onto_fibocoreplus.jsonl
# [agentic_hybrid] kg_artifact=data/kg/fincausal__types=train.csv_skip=0_limit=None__kg.json
# [agentic_hybrid] predict doc-types=all skip=0 limit=None
# [agentic_hybrid] backend=vllm model=openai/gpt-oss-20b
# [agentic_hybrid] few-shots collected: 3
# AgenticHybrid on fincausal: 967doc [31:51,  1.98s/doc]
# [agentic_hybrid] done. predicted=967
# [agentic_hybrid] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/fincausal.agentic_hybrid.vllm.jsonl

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key fincausal \
  --method agentic_hybrid \
  --backend vllm \
  --doc-type all
# Out:
# [eval] dataset-key: fincausal
# [eval] method: agentic_hybrid
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/fincausal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/fincausal.agentic_hybrid.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/fincausal/agentic_hybrid.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.9847
# Recall:    0.9688
# F1:        0.9767
#
# === Counts ===
# TP: 900
# FP: 14
# FN: 29
# num_docs_seen: 967
# num_docs_eval: 967
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# #### Agentic Single Simple RAG

# %%
# %run "scripts/run_langgraph_agentic_simple_relations.py" \
  --dataset-key fincausal \
  --backend vllm \
  --doc-types all \
  --shot-num 3 \
  --shot-doc-types all \
  --max-llm-calls 2
# Out:
# [langgraph_agentic_simple] input=data/preprocessed/fincausal.jsonl
# [langgraph_agentic_simple] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/fincausal.langgraph_agentic_simple.vllm.jsonl
# [langgraph_agentic_simple] predict doc-types=all skip=0 limit=None
# [langgraph_agentic_simple] backend=vllm model=openai/gpt-oss-20b
# [langgraph_agentic_simple] planner_mode=rule max_llm_calls=2 web=True wikidata=True
# [langgraph_agentic_simple] few-shots collected: 3
# LangGraphAgenticSimple on fincausal: 967doc [25:59,  1.61s/doc]
# [langgraph_agentic_simple] done. predicted=967
# [langgraph_agentic_simple] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/fincausal.langgraph_agentic_simple.vllm.jsonl

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key fincausal \
  --method langgraph_agentic_simple \
  --backend vllm \
  --doc-type all
# Out:
# [eval] dataset-key: fincausal
# [eval] method: langgraph_agentic_simple
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/fincausal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/fincausal.langgraph_agentic_simple.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/fincausal/langgraph_agentic_simple.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.9967
# Recall:    0.9806
# F1:        0.9886
#
# === Counts ===
# TP: 911
# FP: 3
# FN: 18
# num_docs_seen: 967
# num_docs_eval: 967
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# ### Maven Ere

# %%
# %run "scripts/build_kg_from_preprocessed.py" \
  --dataset-key maven_ere \
  --doc-types train \
  --skip 0

# %%
try:
    # %run "scripts/run_ontology_linking.py" --dataset-key maven_ere --ontology-key EventKG --method llm_embedding --doc-types all
except Exception as e:
    print(e)

# %% [markdown]
# #### Agent Single Hybrid RAG

# %%
# %run "scripts/run_agentic_hybrid_relations.py" \
  --dataset-key maven_ere \
  --backend vllm \
  --doc-types all \
  --ontology-links-path data/preprocessed/maven_ere_olink_llm_embedding_onto_EventKG.jsonl \
  --ontology-key EventKG \
  --ontology-method llm_embedding \
  --kg-path data/kg/maven_ere__types=train_skip=0_limit=None__kg.json \
  --shot-num 3 \
  --shot-doc-types all \
  --max-llm-calls 1

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key maven_ere \
  --method agentic_hybrid \
  --backend vllm \
  --doc-type all
# Out:
# [eval] dataset-key: maven_ere
# [eval] method: agentic_hybrid
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/maven_ere.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/maven_ere.agentic_hybrid.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/maven_ere/agentic_hybrid.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.1328
# Recall:    0.0817
# F1:        0.1011
#
# === Counts ===
# TP: 3018
# FP: 19701
# FN: 33940
# num_docs_seen: 2870
# num_docs_eval: 2870
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# #### Agentic Single Simple RAG

# %%
# %run "scripts/run_langgraph_agentic_simple_relations.py" \
  --dataset-key maven_ere \
  --backend vllm \
  --doc-types all \
  --shot-num 3 \
  --shot-doc-types all \
  --max-llm-calls 2
# Out:
# [langgraph_agentic_simple] input=data/preprocessed/maven_ere.jsonl
# [langgraph_agentic_simple] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/maven_ere.langgraph_agentic_simple.vllm.jsonl
# [langgraph_agentic_simple] predict doc-types=all skip=0 limit=None
# [langgraph_agentic_simple] backend=vllm model=openai/gpt-oss-20b
# [langgraph_agentic_simple] planner_mode=rule max_llm_calls=2 web=True wikidata=True
# [langgraph_agentic_simple] few-shots collected: 3
# LangGraphAgenticSimple on maven_ere: 3516doc [36:31:09, 37.39s/doc]
# [langgraph_agentic_simple] done. predicted=3516
# [langgraph_agentic_simple] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/maven_ere.langgraph_agentic_simple.vllm.jsonl

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key maven_ere \
  --method langgraph_agentic_simple \
  --backend vllm \
  --doc-type all
# Out:
# [eval] dataset-key: maven_ere
# [eval] method: langgraph_agentic_simple
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/maven_ere.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/maven_ere.langgraph_agentic_simple.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/maven_ere/langgraph_agentic_simple.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.1296
# Recall:    0.0798
# F1:        0.0988
#
# === Counts ===
# TP: 3673
# FP: 24665
# FN: 42341
# num_docs_seen: 3516
# num_docs_eval: 3516
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# ### CausalBank

# %%
try:
    # %run "scripts/run_ontology_linking.py" --dataset-key causalbank --ontology-key wordnetfull --method llm_embedding --doc-types all
except Exception as e:
    print(e)

# %%
# %run "scripts/build_kg_from_preprocessed.py" \
  --dataset-key causalbank \
  --doc-types resulted_from \
  --skip 0

# %% [markdown]
# #### Agent Single Hybrid RAG

# %%
# %run "scripts/run_agentic_hybrid_relations.py" \
  --dataset-key causalbank \
  --backend vllm \
  --doc-types all \
  --ontology-links-path data/preprocessed/causalbank_olink_llm_embedding_onto_wordnetfull.jsonl \
  --ontology-key wordnetfull \
  --ontology-method llm_embedding \
  --kg-path data/kg/causalbank__types=resulted_from_skip=0_limit=None__kg.json \
  --shot-num 3 \
  --shot-doc-types all \
  --max-llm-calls 1
# Out:
# [agentic_hybrid] input=data/preprocessed/causalbank.jsonl
# [agentic_hybrid] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.agentic_hybrid.vllm.jsonl
# [agentic_hybrid] ontology_artifact=data/preprocessed/causalbank_olink_llm_embedding_onto_wordnetfull.jsonl
# [agentic_hybrid] kg_artifact=data/kg/causalbank__types=resulted_from_skip=0_limit=None__kg.json
# [agentic_hybrid] predict doc-types=all skip=0 limit=None
# [agentic_hybrid] backend=vllm model=openai/gpt-oss-20b
# [agentic_hybrid] few-shots collected: 3
# AgenticHybrid on causalbank: 1080doc [14:53:27, 49.64s/doc]
# [agentic_hybrid] done. predicted=1080
# [agentic_hybrid] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.agentic_hybrid.vllm.jsonl

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key causalbank \
  --method agentic_hybrid \
  --backend vllm \
  --doc-type all
# Out:
# [eval] dataset-key: causalbank
# [eval] method: agentic_hybrid
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/causalbank.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.agentic_hybrid.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/causalbank/agentic_hybrid.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.7792
# Recall:    0.3495
# F1:        0.4826
#
# === Counts ===
# TP: 58409
# FP: 16553
# FN: 108701
# num_docs_seen: 1080
# num_docs_eval: 1080
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# #### Agentic Single Simple RAG

# %%
# %run "scripts/run_langgraph_agentic_simple_relations.py" \
  --dataset-key causalbank \
  --backend vllm \
  --doc-types all \
  --shot-num 3 \
  --shot-doc-types all \
  --max-llm-calls 2
# Out:
# [langgraph_agentic_simple] input=data/preprocessed/causalbank.jsonl
# [langgraph_agentic_simple] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.langgraph_agentic_simple.vllm.jsonl
# [langgraph_agentic_simple] predict doc-types=all skip=0 limit=None
# [langgraph_agentic_simple] backend=vllm model=openai/gpt-oss-20b
# [langgraph_agentic_simple] planner_mode=rule max_llm_calls=2 web=True wikidata=True
# [langgraph_agentic_simple] few-shots collected: 3
# LangGraphAgenticSimple on causalbank: 1080doc [11:23:18, 37.96s/doc]
# [langgraph_agentic_simple] done. predicted=1080
# [langgraph_agentic_simple] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.langgraph_agentic_simple.vllm.jsonl

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key causalbank \
  --method langgraph_agentic_simple \
  --backend vllm \
  --doc-type all
# Out:
# [eval] dataset-key: causalbank
# [eval] method: langgraph_agentic_simple
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/causalbank.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.langgraph_agentic_simple.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/causalbank/langgraph_agentic_simple.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.7899
# Recall:    0.3569
# F1:        0.4917
#
# === Counts ===
# TP: 59642
# FP: 15859
# FN: 107468
# num_docs_seen: 1080
# num_docs_eval: 1080
# num_docs_missing_gold: 0
#
# [eval] Done.
