# %% [markdown]
# # Supplementary runtime and CO2 metrics, v2
#
# This notebook runs `scripts/run_supplementary_runtime_co2_v2.py`. It measures one eligible document per method/dataset condition, counts the eligible JSONL documents, and writes CSV/JSON outputs to `data/suplementary_metrics/`.
#
# The values are approximate cost indicators, not exact full-benchmark measurements. Failed runs are kept in the CSV/JSON, but their runtime/CO2 estimates are left blank.

# %%
# Run this notebook from tests/processing/. Move to the project root.
# %cd ../..

# %%
# List all configured method/dataset runs.
# !python scripts/run_supplementary_runtime_co2_v2.py --list

# %%
# Dry run: resolves files and commands without executing the methods.
# In v2, dry-run rows are explicitly marked as DRY-RUN instead of OK.
# !python scripts/run_supplementary_runtime_co2_v2.py --dry-run --show-error-tail 60

# %% [markdown]
# ## Before running the real measurement
#
# The methods use the same backend parameters as the notebooks. Most commands use `--backend vllm`, so make sure the vLLM server is running and reachable through `VLLM_BASE_URL`, usually `http://localhost:8000`.

# %%
# Small test run before launching everything.
# If this fails, inspect the log tail printed below.
# !python scripts/run_supplementary_runtime_co2_v2.py \
  --only-method baseline \
  --only-dataset docred_causal \
  --sample-index 0 \
  --power-kw 0.300 \
  --carbon-intensity 0.045 \
  --show-error-tail 80 \
  --stop-on-error

# %%
# Full supplementary-cost run. This may take a long time because it calls the LLM methods.
# !python scripts/run_supplementary_runtime_co2_v2.py \
  --sample-index 0 \
  --power-kw 0.300 \
  --carbon-intensity 0.045 \
  --show-error-tail 40

# %%
# Inspect the resulting CSV table.
import pandas as pd
from pathlib import Path

csv_path = Path('data/suplementary_metrics/runtime_co2_by_method_dataset.csv')
df = pd.read_csv(csv_path)
df.head()

# %%
# Compact view for the paper table.
cols = [
    'status',
    'method_family',
    'method',
    'dataset',
    'n_eligible_documents',
    'elapsed_seconds_doc',
    'estimated_total_minutes',
    'co2_g_doc',
    'estimated_total_co2_g',
    'log_path',
]
df[cols].sort_values(['method_family', 'method', 'dataset'])
