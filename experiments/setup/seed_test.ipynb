# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys; sys.path.insert(0, "C:/Users/henri/Documents/git/post-doc/ragtree")

# %%
from ragtree.utils.seed import set_seed
set_seed(42)

# %%
# scripts/run_preprocess.py
from ragtree.core.config import load_config
from ragtree.utils.seed import set_seed

cfg = load_config()
set_seed(cfg["project"]["seed"])

print(cfg["paths"]["data_raw"])
# Out:
# data/raw

# %%
from ragtree.core.config import load_config
from ragtree.utils.seed import set_seed
from ragtree.utils.logger import get_logger

cfg = load_config()
set_seed(cfg["project"]["seed"])
logger = get_logger("setup", cfg["project"]["log_dir"])
logger.info("Config loaded.")
# Out:
# [2025-11-03 22:07:04,860] INFO - setup: Config loaded.

# %%
# %run ../../scripts/setup_dirs.py
# Out:
# [2025-11-03 22:11:31,246] INFO - setup_dirs: Ensured folder: C:\Users\henri\Documents\git\post-doc\ragtree\data\raw
# [2025-11-03 22:11:31,247] INFO - setup_dirs: Ensured folder: C:\Users\henri\Documents\git\post-doc\ragtree\data\processed
# [2025-11-03 22:11:31,251] INFO - setup_dirs: Ensured folder: C:\Users\henri\Documents\git\post-doc\ragtree\models
# [2025-11-03 22:11:31,252] INFO - setup_dirs: Ensured folder: C:\Users\henri\Documents\git\post-doc\ragtree\data\kg
# [2025-11-03 22:11:31,253] INFO - setup_dirs: Ensured folder: C:\Users\henri\Documents\git\post-doc\ragtree\results
# [2025-11-03 22:11:31,255] INFO - setup_dirs: Ensured folder: C:\Users\henri\Documents\git\post-doc\ragtree\jsonresults
# [2025-11-03 22:11:31,255] INFO - setup_dirs: All folders created.

# %%
import os
print("Notebook CWD:", os.getcwd())
# Out:
# Notebook CWD: c:\Users\henri\Documents\git\post-doc\ragtree\tests\setup

# %%
cfg = load_config()
logger = get_logger("my_script", cfg["project"]["log_dir"])
data_raw = cfg["paths"]["data_raw"]
