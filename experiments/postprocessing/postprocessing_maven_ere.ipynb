# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Openning data

# %%
# tests/preprocessing/datasets.ipynb
from pathlib import Path
import sys, os

# point to your project root
project_root = Path(r"/home/galencarmedeiro/git/postdoc/ragtree")
#project_root = Path(r"C:\Users\henri\Documents\git\post-doc\ragtree")
os.chdir(project_root)  # so relative paths go to data/, not tests/
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print("CWD:", os.getcwd())
# Out:
# CWD: /home/galencarmedeiro/git/postdoc/ragtree

# %%
# %run "scripts/eval_relations.py" --dataset-key eventstoryline --method baseline --backend vllm --ignore-labels null
# Out:
# [eval] dataset-key: eventstoryline
# [eval] method: baseline
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/eventstoryline.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/eventstoryline.baseline.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/eventstoryline/baseline.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.1436
# Recall:    0.0519
# F1:        0.0762
#
# === Counts ===
# TP: 500
# FP: 2981
# FN: 9140
# num_docs_seen: 443
# num_docs_eval: 443
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# # =========================
# #  BASELINE
# # =========================

# %%
try:
    # %run "scripts/eval_relations.py" --dataset-key docred_causal --method baseline --backend vllm --doc-type test
except Exception as e:
    print(e)
# Out:
# [eval] dataset-key: docred_causal
# [eval] method: baseline
# [eval] backend: vllm
# [eval] doc-type: test
# [eval] gold: data/preprocessed/docred_causal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.baseline.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/docred_causal/baseline.vllm.test.json
#
# === Micro-level metrics ===
# Precision: 0.0000
# Recall:    0.0000
# F1:        0.0000
#
# === Counts ===
# TP: 0
# FP: 6011
# FN: 0
# num_docs_seen: 1000
# num_docs_eval: 1000
# num_docs_missing_gold: 0
#
# [eval] Done.

# %%
print("\n=== BASELINE: causalbank ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key causalbank --method baseline --backend vllm --doc-type all
except Exception as e:
    print(e)

print("\n=== BASELINE: docred_causal ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key docred_causal --method baseline --backend vllm --doc-type all
except Exception as e:
    print(e)

print("\n=== BASELINE: eventstoryline ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key eventstoryline --method baseline --backend vllm --doc-type all
except Exception as e:
    print(e)

print("\n=== BASELINE: fincausal ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key fincausal --method baseline --backend vllm --doc-type all
except Exception as e:
    print(e)

print("\n=== BASELINE: maven_ere ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key maven_ere --method baseline --backend vllm --doc-type all
except Exception as e:
    print(e)
# Out:
# === BASELINE: causalbank ===
# [eval] dataset-key: causalbank
# [eval] method: baseline
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/causalbank.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.baseline.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/causalbank/baseline.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.8124
# Recall:    0.0051
# F1:        0.0101
#
# === Counts ===
# TP: 853
# FP: 197
# FN: 166257
# num_docs_seen: 1080
# num_docs_eval: 1080
# num_docs_missing_gold: 0
#
# [eval] Done.
#
# === BASELINE: docred_causal ===
# [eval] dataset-key: docred_causal
# [eval] method: baseline
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/docred_causal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.baseline.vllm.jsonl
# ...

# %% [markdown]
# # =========================
# #  ICL
# # =========================

# %%
print("\n=== ICL: causalbank ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key causalbank --method icl --backend vllm --doc-type all
except Exception as e:
    print(e)

print("\n=== ICL: docred_causal ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key docred_causal --method icl --backend vllm --doc-type test
except Exception as e:
    print(e)

print("\n=== ICL: eventstoryline ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key eventstoryline --method icl --backend vllm --doc-type all
except Exception as e:
    print(e)

print("\n=== ICL: fincausal ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key fincausal --method icl --backend vllm --doc-type all
except Exception as e:
    print(e)

print("\n=== ICL: maven_ere ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key maven_ere --method icl --backend vllm --doc-type all
except Exception as e:
    print(e)
# Out:
# === ICL: causalbank ===
# [eval] dataset-key: causalbank
# [eval] method: icl
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/causalbank.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.icl.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/causalbank/icl.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.7657
# Recall:    0.0131
# F1:        0.0258
#
# === Counts ===
# TP: 2193
# FP: 671
# FN: 164917
# num_docs_seen: 1080
# num_docs_eval: 1080
# num_docs_missing_gold: 0
#
# [eval] Done.
#
# === ICL: docred_causal ===
# [eval] dataset-key: docred_causal
# [eval] method: icl
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/docred_causal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.icl.vllm.jsonl
# [eval] ignore-labels: ['null']
# ...

# %%
print("\n=== BASELINE: docred_causal (gold from processed) ===")
try:
    # %run "scripts/eval_relations_docred.py" \
        --dataset-key docred_causal \
        --method baseline --backend vllm \
        --gold-path "data/preprocessed/docred_causal.jsonl" \
        --doc-type test
except Exception as e:
    print(e)
# Out:
# === BASELINE: docred_causal (gold from processed) ===
# [eval] dataset-key: docred_causal
# [eval] method: baseline
# [eval] backend: vllm
# [eval] doc-type: test
# [eval] gold: data/preprocessed/docred_causal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.baseline.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/docred_causal/baseline.vllm.test.json
#
# === Micro-level metrics ===
# Precision: 0.0000
# Recall:    0.0000
# F1:        0.0000
#
# === Counts ===
# TP: 0
# FP: 6011
# FN: 0
# num_docs_seen: 1000
# num_docs_eval: 1000
# num_docs_missing_gold: 0
#
# [eval] Done.

# %%
print("\n=== ICL: docred_causal ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key docred_causal --method icl --backend vllm --doc-type test
except Exception as e:
    print(e)
# Out:
# === ICL: docred_causal ===
# [eval] dataset-key: docred_causal
# [eval] method: icl
# [eval] backend: vllm
# [eval] doc-type: test
# [eval] gold: data/preprocessed/docred_causal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.icl.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/docred_causal/icl.vllm.test.json
#
# === Micro-level metrics ===
# Precision: 0.0000
# Recall:    0.0000
# F1:        0.0000
#
# === Counts ===
# TP: 0
# FP: 6412
# FN: 0
# num_docs_seen: 1000
# num_docs_eval: 1000
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# # =========================
# #  CHAIN OF THOUGHT (CoT)
# # =========================

# %%
print("\n=== COT: causalbank ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key causalbank --method cot --backend vllm --doc-type all
except Exception as e:
    print(e)

print("\n=== COT: docred_causal ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key docred_causal --method cot --backend vllm --doc-type test
except Exception as e:
    print(e)

print("\n=== COT: eventstoryline ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key eventstoryline --method cot --backend vllm --doc-type all
except Exception as e:
    print(e)

print("\n=== COT: fincausal ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key fincausal --method cot --backend vllm --doc-type all
except Exception as e:
    print(e)

print("\n=== COT: maven_ere ===")
try:
    # %run "scripts/eval_relations.py" --dataset-key maven_ere --method cot --backend vllm --doc-type all
except Exception as e:
    print(e)
# Out:
# === COT: causalbank ===
# [eval] dataset-key: causalbank
# [eval] method: cot
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/causalbank.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.cot.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/causalbank/cot.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.7256
# Recall:    0.0080
# F1:        0.0158
#
# === Counts ===
# TP: 1333
# FP: 504
# FN: 165777
# num_docs_seen: 1080
# num_docs_eval: 1080
# num_docs_missing_gold: 0
#
# [eval] Done.
#
# === COT: docred_causal ===
# [eval] dataset-key: docred_causal
# [eval] method: cot
# [eval] backend: vllm
# [eval] doc-type: test
# [eval] gold: data/preprocessed/docred_causal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.cot.vllm.jsonl
# [eval] ignore-labels: ['null']
# ...
