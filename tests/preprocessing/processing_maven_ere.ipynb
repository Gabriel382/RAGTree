# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Openning data

# %%
# tests/preprocessing/datasets.ipynb
from pathlib import Path
import sys, os

# point to your project root
project_root = Path(r"C:\Users\henri\Documents\git\post-doc\ragtree")
os.chdir(project_root)  # so relative paths go to data/, not tests/
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print("CWD:", os.getcwd())
# Out:
# CWD: C:\Users\henri\Documents\git\post-doc\ragtree

# %%
# %run "scripts/run_single_llm_baseline.py" --dataset-key maven_ere --backend vllm
# Out:
# [baseline] dataset-key=maven_ere
# [baseline] backend=vllm, model=openai/gpt-oss-20b
# [baseline] input=data\preprocessed\maven_ere.jsonl
# [baseline] output=C:\Users\henri\Documents\git\post-doc\ragtree\data\processed\maven_ere.baseline.vllm.jsonl
# 0it [00:00, ?it/s]
# {'role': 'user', 'content': 'You are given a sentence (and optionally a title) plus a list of entities with IDs.\nYour **only** task is to extract binary relations between entities, using only the following relation types:\n\n  CAUSE, PRECONDITION\n\nYou must output a JSON object where:\n  - each key is one of the relation types above, and\n  - each value is a list of pairs [head_entity_id, tail_entity_id].\n\nIf there are no relations of a given type, use an empty list [].\n\nDo not invent new relation type names. Use only the relation types listed.\n\nTitle:\nExpedition of the Thousand\n\nSentence:\nThe Expedition of the Thousand (Italian "Spedizione dei Mille") was an event of the Italian Risorgimento that took place in 1860. A corps of volunteers led by Giuseppe Garibaldi sailed from Quarto, near Genoa (now Quarto dei Mille) and landed in Marsala, Sicily, in order to conquer the Kingdom of the Two Sicilies, ruled by the House of Bourbon-Two Sicilies. The project was an ambitious and risky venture aiming to conquer, with a thousand men, a kingdom with a larger regular army and a more powerful navy. The expedition was a success and concluded with a plebiscite that brought Naples and Sicily into the Kingdom of Sardinia, the last territorial conquest before the creation of the Kingdom of Italy on 17 March 1861. The sea venture was the only desired action that was jointly decided by the "four fathers of the nation" Giuseppe Mazzini, Giuseppe Garibaldi, Victor Emmanuel II, and Camillo Cavour, pursuing divergent goals. However, the Expedition was instigated by Francesco Crispi, who utilized his political influence to bolster the Italian unification project. The various groups participated in the expedition for a variety of reasons: for Garibaldi, it was to achieve a united Italy; to the Sicilian bourgeoisie, an independent Sicily as part of the kingdom of Italy, and for common people, land distribution and the end of oppression.\n\nEntities:\n- EVENT_e2cbbfb4a5ab65856ccc7057443120e0: "ruled" [Control] (span: 38-39) (mention_id=d67d19cc8d3a9346e6dbea2a76a6d1d9, sent_id=1)\n- EVENT_0b0c5d1268cc135278489b7f0004c0c3: "achieve" [Achieve] (span: 19-20) (mention_id=320034839ed983559b96fdbefa7d3dc0, sent_id=6)\n- EVENT_e71684bf9f6e7b50bf5316982a640c15: "creation" [Creating] (span: 27-28) (mention_id=ee662538dab38ae06acd111c81cd5604, sent_id=3)\n- EVENT_f535eb21f8f958a04cbc69c1d1521186: "Expedition" [Self_motion] (span: 1-2) (mention_id=ba52b07af376a19bff47136177244b96, sent_id=0)\n- EVENT_f535eb21f8f958a04cbc69c1d1521186: "venture" [Self_motion] (span: 7-8) (mention_id=e52fe3ae0d43ed54c49d5980771c1a8a, sent_id=2)\n- EVENT_f535eb21f8f958a04cbc69c1d1521186: "expedition" [Self_motion] (span: 1-2) (mention_id=f89b405432358e6de5ad252c2c8d38d8, sent_id=3)\n- EVENT_f535eb21f8f958a04cbc69c1d1521186: "Expedition" [Self_motion] (span: 3-4) (mention_id=cd02764a98a51fb3ec943f7807dbe24d, sent_id=5)\n- EVENT_f535eb21f8f958a04cbc69c1d1521186: "expedition" [Self_motion] (span: 6-7) (mention_id=e3d0b625f8d6c3f0e8a80671e9a0455c, sent_id=6)\n- EVENT_d2587256a67ce75ea9d9d864288d822c: "landed" [Motion] (span: 21-22) (mention_id=187955a9227516bae5cf7198e30a3cd4, sent_id=1)\n- EVENT_e12e909ff79793dc2b7b534d37685e9c: "instigated" [Process_start] (span: 5-6) (mention_id=458c67e4a792cb6ab5d3d727869cfa08, sent_id=5)\n- EVENT_f652152ef7245a6f5c27396a2b1964e1: "concluded" [Process_end] (span: 6-7) (mention_id=d0056d86b2a8e2b93b52ccb7d8b62258, sent_id=3)\n- EVENT_15451e1aabcb291d411af6a3d7e32911: "unification" [Cause_to_amalgamate] (span: 19-20) (mention_id=474369e57a50e78508884e8337d42156, sent_id=5)\n- EVENT_6912f3e89bb068b0fdd78948b8cb9be2: "aiming" [Aiming] (span: 8-9) (mention_id=5d23362ab48caec56d74811d45f2ba12, sent_id=2)\n- EVENT_93e0350c5f49e6ddb79b2091fda2012a: "brought" [Bringing] (span: 11-12) (mention_id=522c38eea91e76e49ffbf761a9ce7d10, sent_id=3)\n- EVENT_223bc4cd361349a0bd7fbd0065eb0f7d: "participated" [Participation] (span: 3-4) (mention_id=5d479bcea ...
# 1it [00:17, 17.24s/it]
# {'role': 'user', 'content': 'You are given a sentence (and optionally a title) plus a list of entities with IDs.\nYour **only** task is to extract binary relations between entities, using only the following relation types:\n\n  CAUSE, PRECONDITION\n\nYou must output a JSON object where:\n  - each key is one of the relation types above, and\n  - each value is a list of pairs [head_entity_id, tail_entity_id].\n\nIf there are no relations of a given type, use an empty list [].\n\nDo not invent new relation type names. Use only the relation types listed.\n\nTitle:\nMurder of Leigh Leigh\n\nSentence:\nThe murder of Leigh Leigh, born Leigh Rennea Mears, occurred on 3 November 1989 while she was attending a 16-year-old boy\'s birthday party at Stockton Beach, New South Wales, on the east coast of Australia. The 14-year-old girl from Fern Bay was assaulted by a group of boys after she returned distressed from a sexual encounter on the beach that a reviewing judge later called non-consensual. After being kicked and spat on by the group, Leigh left the party. Her naked body was found in the sand dunes nearby the following morning, with severe genital damage and a crushed skull. Matthew Grant Webster, an 18-year-old who acted as a bouncer at the event, pleaded guilty to her murder and was sentenced to 20 years in prison with a 14-year non-parole period. He was released on parole in June 2004, after serving 14½ years. Guy Charles Wilson, the other bouncer and only other person aged over 18 at the party, pleaded guilty to assault; a third male (aged 15) pleaded guilty to having sex with a minor. The investigation of Leigh\'s murder proved controversial, however, as several people who admitted to various crimes, including assaulting Leigh, were never charged; nor was anyone ever charged with her sexual assault. Webster\'s confession did not match the forensic evidence. The murder investigation was reviewed by the New South Wales Crime Commission in 1996, and by the Police Integrity Commission in 1998, with the latter recommending the dismissal of the detective in charge of the investigation. Leigh\'s murder received considerable attention in the media. Initially focusing on her sexual assault and murder, media attention later concentrated more on the lack of parental supervision and the drugs and alcohol at the party, and on Leigh\'s sexuality. The media coverage of the murder has been cited as an example of blaming the victim. Leigh\'s murder inspired a theatrical play entitled "A Property of the Clan", which was later revised and renamed "Blackrock", as well as a feature film of the same name.\n\nEntities:\n- EVENT_36fe15f2ecceb14abdedc904976ed5aa: "recommending" [Convincing] (span: 27-28) (mention_id=0e76e069cdcdd1f7ff9488f1b40a65d8, sent_id=9)\n- EVENT_9424f1b2452e2a1b4550890e6d4d4605: "renamed" [Name_conferral] (span: 21-22) (mention_id=369fe48ac27852e2c44a3516f060ff1c, sent_id=13)\n- EVENT_40c838f87021aea782979dda7d1e218c: "charged" [Judgment_communication] (span: 26-27) (mention_id=ee1770f040ca9bedbc1a73fe6e9daf2c, sent_id=7)\n- EVENT_5389810ea556a9d008dd6d5b58e53751: "kicked" [Self_motion] (span: 2-3) (mention_id=589b98371559c6af7c75842478f20930, sent_id=2)\n- EVENT_5ac6fb32c1bcdbe3db31fe40c09bc9bf: "pleaded" [Request] (span: 18-19) (mention_id=00d8f4c0e88b652435966a39c8c0c760, sent_id=6)\n- EVENT_ad5f54e6c5e99b350440a6522904c7d6: "focusing" [Aiming] (span: 1-2) (mention_id=12fb1e8b6e32d112e191111b0c5f4ba6, sent_id=11)\n- EVENT_8139a667841b690aa2836529b1aebea4: "serving" [Assistance] (span: 10-11) (mention_id=aa2b34963607b664bd63734276e5385a, sent_id=5)\n- EVENT_77c5bbce3ff0b62b706cf77c998a64cd: "assaulted" [Attack] (span: 7-8) (mention_id=62cdcf3d7c8cd39c8612d4e609c5230e, sent_id=1)\n- EVENT_0e6724982bfe0fc308607e61bb8dfd74: "sentenced" [Legal_rulings] (span: 22-23) (mention_id=d23e81a3c7dfb1a25a29c20c93b7dfdb, sent_id=4)\n- EVENT_f53be1f24a44da8501d7c9e0fc32d9d1: "called" [Name_conferral] (span: 29-30) (mention_id=0a632a6079c7dbdd ...
# 2it [00:30, 14.86s/it]
# {'role': 'user', 'content': 'You are given a sentence (and optionally a title) plus a list of entities with IDs.\nYour **only** task is to extract binary relations between entities, using only the following relation types:\n\n  CAUSE, PRECONDITION\n\nYou must output a JSON object where:\n  - each key is one of the relation types above, and\n  - each value is a list of pairs [head_entity_id, tail_entity_id].\n\nIf there are no relations of a given type, use an empty list [].\n\nDo not invent new relation type names. Use only the relation types listed.\n\nTitle:\nHurricane Jerry (1989)\n\nSentence:\nHurricane Jerry caused minor damage in Texas and flash flooding in Kentucky and Virginia in October 1989. The fourteenth tropical cyclone, tenth named storm of the season, Jerry developed from a tropical wave in the Bay of Campeche on October 12. Initially a tropical depression, the system moved north-northwestward across the Gulf of Mexico and strengthened into Tropical Storm Jerry early on the following day. Jerry continuously deepened until October 14 and then maintained intensity while curving northeastward and briefly decelerating. Later that day, the storm re-curved north-northwestward. Jerry began to intensify on October 15 and soon became a Category 1 hurricane on the Saffir–Simpson hurricane wind scale. Early on October 16, Jerry made landfall on Galveston Island, Texas with winds of . Less than six hours later, Jerry weakened to a tropical storm and then a tropical depression shortly thereafter. Late on October 16, Jerry was absorbed by a frontal system while situated over southwestern Arkansas. Storm surge and rough surf along the coast of Texas destroyed a section of Texas State Highway 87, which was never repaired. Due to strong winds, about 52,000 homes and businesses were left without electricity, most of them in the Galveston area. Many homes, businesses, and buildings were inflicted damage because of strong winds and three tornadoes spawned by the storm. Despite the issuance of a hurricane warning just eight hours prior to landfall, Jerry caused only three fatalities in Texas, possibly due to the storm\'s small size; a car fell over the Galveston Seawall, killing its three occupants. Minor wind and coastal flood damage was reported in Louisiana. Jerry and its remnants brought flash flooding to portions of the Upland South, particularly in the states of Kentucky, Virginia, and West Virginia. In eastern Kentucky, hundreds of homes were flooded and many bridges, culverts, and roads were washed out; this left hundreds of residents stranded. Damage in Kentucky reached at least $5 million. Similar impact occurred in Virginia; with $3.4 million (1989 USD) in damage in Buchanan County. In West Virginia, overflowing rivers in the western portions of the state forced hundreds to evacuate. Throughout the United States, Jerry resulted in about $70 million in damage.\n\nEntities:\n- EVENT_70824ec59e32d4f9f1edc2ba7e80ab90: "fell" [Motion] (span: 33-34) (mention_id=f3a7903e62d6a0c39f6de6840f58a3da, sent_id=12)\n- EVENT_6f6b8673d098cd0aaa97bceeb302674c: "occurred" [Coming_to_be] (span: 2-3) (mention_id=ee7567c302e7ac7103cb5a262659e29c, sent_id=17)\n- EVENT_86f3e66fd22e185f6c132d1c197ebd31: "caused" [Causation] (span: 15-16) (mention_id=ba2e82e63765850fb1e736eead3dd8a4, sent_id=12)\n- EVENT_cf4b81a7ad9f39307502eb49834092f7: "Damage" [Damaging] (span: 0-1) (mention_id=f0f068965d53b2f3fb971965a4f303ba, sent_id=16)\n- EVENT_365c60e7cad228a99ea281ea5131651c: "situated" [Placing] (span: 13-14) (mention_id=bbd95c7574a6121aae3ab56a57b0ed1d, sent_id=8)\n- EVENT_9f6f6fe534557ce6cfae4e1112bd7e9b: "made" [Manufacturing] (span: 6-7) (mention_id=427d8c0e541452a81ca9a202f273d7a4, sent_id=6)\n- EVENT_f444a52cf6695b576d0b7605584dfaee: "flooding" [Motion] (span: 6-7) (mention_id=202a2bd4cf1500730b67f88ed388717c, sent_id=14)\n- EVENT_ff67303f3677d7116ea4b12642a7d19d: "named" [Name_conferral] (span: 6-7) (mention_id=00f10b48f1fc18f2c6515991ee2f9ea1, se ...
# 3it [00:46, 15.20s/it]
# {'role': 'user', 'content': 'You are given a sentence (and optionally a title) plus a list of entities with IDs.\nYour **only** task is to extract binary relations between entities, using only the following relation types:\n\n  CAUSE, PRECONDITION\n\nYou must output a JSON object where:\n  - each key is one of the relation types above, and\n  - each value is a list of pairs [head_entity_id, tail_entity_id].\n\nIf there are no relations of a given type, use an empty list [].\n\nDo not invent new relation type names. Use only the relation types listed.\n\nTitle:\nDeath of Christopher Alder\n\nSentence:\nChristopher Alder was a trainee computer programmer and former British Army paratrooper who had served in the Falklands War and was commended for his service with the Army in Northern Ireland. He died while in police custody at Queen\'s Gardens Police Station, Kingston upon Hull, in April 1998. The case became a cause célèbre for civil rights campaigners in the United Kingdom. He had earlier been the victim of an assault outside a nightclub and was taken to Hull Royal Infirmary where, possibly as a result of his head injury, staff said his behaviour was "extremely troublesome." He was escorted from the hospital by two police officers who arrested him to prevent a breach of the peace. On arrival at the police station Alder was "partially dragged and partially carried," handcuffed and unconscious, from a police van and placed on the floor of the custody suite. Officers chatted between themselves and speculated that he was faking illness. Twelve minutes later one of the officers present noticed that Alder was not making any breathing noises and although resuscitation was attempted, he was pronounced dead at the scene. A post mortem indicated that the head injury alone would not have killed him. The incident was captured on the police station\'s closed-circuit television (CCTV) cameras. A coroner\'s jury in 2000 returned a verdict that Alder was unlawfully killed. In 2002 five police officers went on trial charged with Alder\'s manslaughter and misconduct in public office, but were acquitted on the orders of the judge. In 2006 an Independent Police Complaints Commission report concluded that four of the officers present in the custody suite when Alder died were guilty of the "most serious neglect of duty". In November 2011 the government formally apologised to Alder\'s family in the European Court of Human Rights, admitting that it had breached its obligations with regard to "preserving life and ensuring no one is subjected to inhuman or degrading treatment". They also admitted that they had failed to carry out an effective and independent inquiry into the case.\n\nEntities:\n- EVENT_3ccd4f275de7691f301ab49019a1f7c5: "preserving" [Preserving] (span: 30-31) (mention_id=c9c813414916759ca999bdcbed4b5e77, sent_id=13)\n- EVENT_2f8aae6529bb71a82b60c8da268eb782: "admitted" [Reveal_secret] (span: 2-3) (mention_id=a0c2d517d6ba3fe9c7387cbc0340b517, sent_id=14)\n- EVENT_024c938b9f4dbe19c5549dbfc92cb328: "escorted" [Patrolling] (span: 2-3) (mention_id=35ce6e78559c7505cbe75a2659df57f3, sent_id=4)\n- EVENT_c11a88376fbbc0ec72a90da72845c09f: "carried" [Carry_goods] (span: 13-14) (mention_id=167a5b3e17e3985108f28917e0fd4a45, sent_id=5)\n- EVENT_38fced5f4ff38829319f42024cbb239b: "assault" [Attack] (span: 8-9) (mention_id=43153317d708992516cb56be2786c450, sent_id=3)\n- EVENT_f554f9b20e32e2d478835fb51a0fc24c: "noticed" [Know] (span: 8-9) (mention_id=74756a88aa8edaf7d8ac62e85b4cf9df, sent_id=7)\n- EVENT_529fb1a94861f0ec0205972716ef08e1: "inquiry" [Criminal_investigation] (span: 14-15) (mention_id=eeed9784599f40a3ff701dc2815877cd, sent_id=14)\n- EVENT_f484a1f93f74f5bab552a236f111aa25: "guilty" [Committing_crime] (span: 23-24) (mention_id=25ee3d5565f9c693d3c1e7f200a6fde0, sent_id=12)\n- EVENT_b6972d571bb31ae66692b8d08cf84592: "killed" [Killing] (span: 13-14) (mention_id=86c6f44976e16073a77f7f1ef4d18409, sent_id=10)\n- EVENT_d9ad5f5f0adc357a7ed104af3e4d5e82 ...
# 4it [01:01, 15.38s/it]
# {'role': 'user', 'content': 'You are given a sentence (and optionally a title) plus a list of entities with IDs.\nYour **only** task is to extract binary relations between entities, using only the following relation types:\n\n  CAUSE, PRECONDITION\n\nYou must output a JSON object where:\n  - each key is one of the relation types above, and\n  - each value is a list of pairs [head_entity_id, tail_entity_id].\n\nIf there are no relations of a given type, use an empty list [].\n\nDo not invent new relation type names. Use only the relation types listed.\n\nTitle:\nClackamas Town Center shooting\n\nSentence:\nOn December 11, 2012, a shooting occurred at the Clackamas Town Center in unincorporated Clackamas County, outside the city of Portland, Oregon, United States. The gunman, 22-year-old Jacob Tyler Roberts, ran into the shopping center wearing tactical clothing and a hockey mask and opened fire on shoppers and employees with a stolen Stag Arms AR-15 rifle. He fired a total of 17 shots, killing two people and seriously wounding a third. Having attempted to reload his weapon and dropping three magazines, Roberts entered a stairwell and committed suicide after descending one level because he encountered someone with a concealed carry permit who had drawn his gun. He had no connection to any of his victims, and it was believed to be a random act of violence. The Clackamas Town Center has a posted policy of prohibiting firearms on the premises.\n\nEntities:\n- EVENT_422ed35102bdb680bc098aa3a94a724b: "suicide" [Killing] (span: 17-18) (mention_id=2182f0910a9501fbc050d5e7383e7982, sent_id=3)\n- EVENT_9590eefd428bcee365ddf8df71f6294b: "ran" [Self_motion] (span: 8-9) (mention_id=df72351155272811394fe3591def1d43, sent_id=1)\n- EVENT_467a65124e06a33e7b8b37f6848f14ef: "committed" [Committing_crime] (span: 16-17) (mention_id=bd4edf4168c59949be557f348c218b6d, sent_id=3)\n- EVENT_36fb836332007359ad085f8f6f6d7f48: "occurred" [Coming_to_be] (span: 8-9) (mention_id=543d2b5df942eb09ace0fc8bac804a9a, sent_id=0)\n- EVENT_697a06d1d172abef670f3dfd3c353862: "drawn" [Motion] (span: 33-34) (mention_id=dc67de57a3623f2f16a05faec468c737, sent_id=3)\n- EVENT_7fa8ef0a48f0d82a7da1c060077e571a: "descending" [Motion_directional] (span: 19-20) (mention_id=360703d79ffb057cdc6894e3ed04bdce, sent_id=3)\n- EVENT_2ba609b3aacac38e6c2b84e009a1cd90: "fired" [Use_firearm] (span: 1-2) (mention_id=c5a6653b500009eec2d17d1490d1f7d4, sent_id=2)\n- EVENT_413c88546068f1e94c400eccd202a987: "fire" [Use_firearm] (span: 22-23) (mention_id=cc46880c283529ae402cc8cffcfdaafb, sent_id=1)\n- EVENT_fd971030f35f067fe1a616818b5fb4b8: "dropping" [Body_movement] (span: 7-8) (mention_id=b4089913ff39385d59ceae03136eed48, sent_id=3)\n- EVENT_ce4bef9f5ba9605323ca2c33ccf4c81e: "shooting" [Use_firearm] (span: 7-8) (mention_id=5607068860ff23cabf2cbfa8a79d3d4b, sent_id=0)\n- EVENT_93afd9d004189af595b6a9e514b7fe57: "prohibiting" [Preventing_or_letting] (span: 9-10) (mention_id=1a39c7b579682b71bfa85eff55d1b896, sent_id=5)\n- EVENT_23d17d77282e3a2639abb03e7ed68649: "killing" [Killing] (span: 8-9) (mention_id=809cb9684a6439d2fbb792df1623e220, sent_id=2)\n- EVENT_d360c082c167942f763e90550f9f6baf: "wounding" [Bodily_harm] (span: 13-14) (mention_id=4aa105e42721800cd0314a6523e42736, sent_id=2)\n- EVENT_d31237a3dc4e16865b2147afd03e444f: "believed" [Know] (span: 13-14) (mention_id=ec2b071d3c9771e6337a213aa6bc20b5, sent_id=4)\n- EVENT_38dc7006c11a2ba97036ba4f849026eb: "wearing" [Wearing] (span: 13-14) (mention_id=615e36e8a0a8508c90ba27563a5a4572, sent_id=1)\n- EVENT_9bc177cfd64c67c8c9f1cbcb90b5582a: "entered" [Arriving] (span: 12-13) (mention_id=b452e97d220a9cf83f39d496bc361975, sent_id=3)\n- EVENT_d210b4e2545143c8e26e40f9ebd15f29: "violence" [Violence] (span: 20-21) (mention_id=30350df2c311727300fbe6fc3c630e5f, sent_id=4)\n\nNow output ONLY the JSON object. Do not include any explanation or text outside the JSON.'}
# 5it [01:07, 13.47s/it]
# [baseline] Done. Processed 5 documents.
