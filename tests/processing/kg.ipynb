# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Openning data

# %%
# tests/preprocessing/datasets.ipynb
from pathlib import Path
import sys, os

# point to your project root
project_root = Path(r"/home/galencarmedeiro/git/postdoc/ragtree")
#project_root = Path(r"C:\Users\henri\Documents\git\post-doc\ragtree")
os.chdir(project_root)  # so relative paths go to data/, not tests/
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print("CWD:", os.getcwd())
# Out:
# CWD: /home/galencarmedeiro/git/postdoc/ragtree

# %% [markdown]
# # DOCRED

# %% [markdown]
# #### BYOKG

# %%
# %run "scripts/build_kg_from_preprocessed.py" \
  --dataset-key docred_causal \
  --doc-types train_annotated \
  --skip 0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/git/postdoc/ragtree/scripts/build_kg_from_preprocessed.py:179
#     175     print("[kg] stats:", payload["stats"])
#     178 if __name__ == "__main__":
# --> 179     main()
#
# File ~/git/postdoc/ragtree/scripts/build_kg_from_preprocessed.py:131, in main()
#     128 num_docs = 0
#     129 num_triples = 0
# --> 131 for doc in _iter_docs(input_path, doc_types=doc_types, skip=args.skip, limit=args.limit):
#     132     num_docs += 1
#     134     # Add entity nodes (optional but helpful)
#
# File ~/git/postdoc/ragtree/scripts/build_kg_from_preprocessed.py:40, in _iter_docs(path, doc_types, skip, limit)
#      38 if not line:
#      39     continue
# ---> 40 doc = json.loads(line)
#      42 # 1) doc-type filter
#      43 if doc_types != "all":
#
# File /usr/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /usr/lib/python3.12/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)    350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %%
# %run "scripts/run_kg_rag_relations.py" \
  --dataset-key docred_causal \
  --backend vllm \
  --doc-type-filter dev \
  --kg-path data/kg/docred_causal__types=train_annotated_skip=0_limit=None__kg.json
# Out:
# [runner] dataset-key=docred_causal
# [runner] method=kg_rag
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/docred_causal.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.kg_rag.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=dev
# [runner] skip=0, limit=None
# [runner] Loaded DocRED rel_info with 96 entries.
# Running kg_rag on docred_causal: 106924doc [7:08:48,  4.16doc/s]
# [runner] Done. Processed 998 documents.
# [runner] docs_after_type_filter=998, skip=0, limit=None
# [runner] Skipped 105926 documents due to doc-type filter.

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key docred_causal \
  --method kg_rag \
  --backend vllm \
  --doc-type dev
# Out:
# [eval] dataset-key: docred_causal
# [eval] method: kg_rag
# [eval] backend: vllm
# [eval] doc-type: dev
# [eval] gold: data/preprocessed/docred_causal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/docred_causal.kg_rag.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/docred_causal/kg_rag.vllm.dev.json
#
# === Micro-level metrics ===
# Precision: 0.9717
# Recall:    0.0896
# F1:        0.1641
#
# === Counts ===
# TP: 1100
# FP: 32
# FN: 11175
# num_docs_seen: 998
# num_docs_eval: 998
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# #### CommunityRAG

# %%
# %run "scripts/build_community_kgrag_index.py" \
  --dataset-key docred_causal \
  --kg-path data/kg/docred_causal__types=train_annotated_skip=0_limit=None__kg.json \
  --output-dir data/kg_community \
  --build-sentence-index

# %%
# %run "scripts/run_community_kgrag_relations.py" \
  --dataset-key docred_causal \
  --communitykg-root data/kg_community \
  --backend vllm \
  --doc-types dev \
  --top-communities 50 \
  --top-sentences 12

# %% [markdown]
# #### Triple KG RAG

# %%
# %run "scripts/run_triple_kg_rag_relations.py" \
  --dataset-key docred_causal \
  --backend vllm \
  --doc-type-filter dev \
  --kg-path data/kg/docred_causal__types=train_annotated_skip=0_limit=None__kg.json \
  --skip 0 \
  --limit null \
  --kg-max-hops 1 \
  --kg-max-triples 120

# %% [markdown]
# # EventStoryLine

# %%
# %run "scripts/build_kg_from_preprocessed.py" \
  --dataset-key eventstoryline \
  --doc-types full \
  --limit 10
# Out:
# [kg] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/kg/eventstoryline__types=full_skip=0_limit=10__kg.json
# [kg] stats: {'num_docs': 10, 'num_triples': 147, 'num_nodes': 119, 'num_edges': 147}

# %% [markdown]
# #### BYOKG

# %%
# %run "scripts/run_kg_rag_relations.py" \
  --dataset-key eventstoryline \
  --backend vllm \
  --doc-type-filter full \
  --kg-path data/kg/eventstoryline__types=full_skip=0_limit=10__kg.json
# Out:
# [runner] dataset-key=eventstoryline
# [runner] method=kg_rag
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/eventstoryline.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/eventstoryline.kg_rag.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=full
# [runner] skip=0, limit=None
# Running kg_rag on eventstoryline: 443doc [1:23:44, 11.34s/doc]
# [runner] Done. Processed 254 documents.
# [runner] docs_after_type_filter=254, skip=0, limit=None
# [runner] Skipped 189 documents due to doc-type filter.

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key eventstoryline \
  --method kg_rag \
  --backend vllm \
  --doc-type full
# Out:
# [eval] dataset-key: eventstoryline
# [eval] method: kg_rag
# [eval] backend: vllm
# [eval] doc-type: full
# [eval] gold: data/preprocessed/eventstoryline.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/eventstoryline.kg_rag.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/eventstoryline/kg_rag.vllm.full.json
#
# === Micro-level metrics ===
# Precision: 0.2776
# Recall:    0.0757
# F1:        0.1189
#
# === Counts ===
# TP: 428
# FP: 1114
# FN: 5228
# num_docs_seen: 254
# num_docs_eval: 254
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# # FinCausal

# %%
# %run "scripts/build_kg_from_preprocessed.py" \
  --dataset-key fincausal \
  --doc-types train.csv \
  --skip 0
# Out:
# [kg] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/kg/fincausal__types=train.csv_skip=0_limit=None__kg.json
# [kg] stats: {'num_docs': 24, 'num_triples': 24, 'num_nodes': 48, 'num_edges': 24}

# %%
# %run "scripts/run_kg_rag_relations.py" \
  --dataset-key fincausal \
  --backend vllm \
  --doc-type-filter all \
  --kg-path data/kg/fincausal__types=train.csv_skip=0_limit=None__kg.json
# Out:
# [runner] dataset-key=fincausal
# [runner] method=kg_rag
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/fincausal.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/fincausal.kg_rag.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=all
# [runner] skip=0, limit=None
# Running kg_rag on fincausal: 967doc [28:55,  1.79s/doc]
# [runner] Done. Processed 967 documents.
# [runner] docs_after_type_filter=967, skip=0, limit=None

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key fincausal \
  --method kg_rag \
  --backend vllm \
  --doc-type all
# Out:
# [eval] dataset-key: fincausal
# [eval] method: kg_rag
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/fincausal.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/fincausal.kg_rag.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/fincausal/kg_rag.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.9868
# Recall:    0.9666
# F1:        0.9766
#
# === Counts ===
# TP: 898
# FP: 12
# FN: 31
# num_docs_seen: 967
# num_docs_eval: 967
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# # Maven Ere

# %%
# %run "scripts/build_kg_from_preprocessed.py" \
  --dataset-key maven_ere \
  --doc-types train \
  --skip 0
# Out:
# [kg] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/kg/maven_ere__types=train_skip=0_limit=None__kg.json
# [kg] stats: {'num_docs': 2828, 'num_triples': 36316, 'num_nodes': 67146, 'num_edges': 36316}

# %%
# %run "scripts/run_kg_rag_relations.py" \
  --dataset-key maven_ere \
  --backend vllm \
  --doc-type-filter all \
  --kg-path data/kg/maven_ere__types=train_skip=0_limit=None__kg.json
# Out:
# [runner] dataset-key=maven_ere
# [runner] method=kg_rag
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/maven_ere.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/maven_ere.kg_rag.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=all
# [runner] skip=0, limit=None
# Running kg_rag on maven_ere: 3516doc [15:58:54, 16.36s/doc]
# [runner] Done. Processed 3516 documents.
# [runner] docs_after_type_filter=3516, skip=0, limit=None

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key maven_ere \
  --method kg_rag \
  --backend vllm \
  --doc-type all
# Out:
# [eval] dataset-key: maven_ere
# [eval] method: kg_rag
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/maven_ere.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/maven_ere.kg_rag.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/maven_ere/kg_rag.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.9086
# Recall:    0.6968
# F1:        0.7887
#
# === Counts ===
# TP: 32063
# FP: 3226
# FN: 13951
# num_docs_seen: 3516
# num_docs_eval: 3516
# num_docs_missing_gold: 0
#
# [eval] Done.

# %% [markdown]
# #### Triple KG RAG

# %%
# %run "scripts/run_triple_kg_rag_relations.py" \
  --dataset-key docred_causal \
  --kg-dir data/kg/docred_causal \
  --backend vllm \
  --doc-types dev \
  --top-k-triples 20

# %% [markdown]
# # CausalBank

# %%
# %run "scripts/build_kg_from_preprocessed.py" \
  --dataset-key causalbank \
  --doc-types resulted_from \
  --skip 0
# Out:
# [kg] wrote: /home/galencarmedeiro/git/postdoc/ragtree/data/kg/causalbank__types=resulted_from_skip=0_limit=None__kg.json
# [kg] stats: {'num_docs': 20, 'num_triples': 2402, 'num_nodes': 173, 'num_edges': 2402}

# %%
# %run "scripts/run_kg_rag_relations.py" \
  --dataset-key causalbank \
  --backend vllm \
  --doc-type-filter all \
  --kg-path data/kg/causalbank__types=resulted_from_skip=0_limit=None__kg.json
# Out:
# [runner] dataset-key=causalbank
# [runner] method=kg_rag
# [runner] backend=vllm, model=openai/gpt-oss-20b
# [runner] input=data/preprocessed/causalbank.jsonl
# [runner] output=/home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.kg_rag.vllm.jsonl
# [runner] output-format=full
# [runner] doc-type-filter=all
# [runner] skip=0, limit=None
# Running kg_rag on causalbank: 1080doc [2:31:07,  8.40s/doc]
# [runner] Done. Processed 1080 documents.
# [runner] docs_after_type_filter=1080, skip=0, limit=None

# %%
# %run "scripts/eval_relations.py" \
  --dataset-key causalbank \
  --method kg_rag \
  --backend vllm \
  --doc-type all
# Out:
# [eval] dataset-key: causalbank
# [eval] method: kg_rag
# [eval] backend: vllm
# [eval] doc-type: all
# [eval] gold: data/preprocessed/causalbank.jsonl
# [eval] preds: /home/galencarmedeiro/git/postdoc/ragtree/data/processed/causalbank.kg_rag.vllm.jsonl
# [eval] ignore-labels: ['null']
# [eval] metrics-out: /home/galencarmedeiro/git/postdoc/ragtree/results/relations/causalbank/kg_rag.vllm.all.json
#
# === Micro-level metrics ===
# Precision: 0.8162
# Recall:    0.0112
# F1:        0.0222
#
# === Counts ===
# TP: 1878
# FP: 423
# FN: 165232
# num_docs_seen: 1080
# num_docs_eval: 1080
# num_docs_missing_gold: 0
#
# [eval] Done.
